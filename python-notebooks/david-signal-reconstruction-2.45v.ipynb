# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# load files 3.3V CSV
broad_signal_3_3 = pd.read_csv('../data/broad2.Wfm.csv', delimiter=';', names=['near_end', 'far_end'])
strip_signal_3_3 = pd.read_csv('../data/strip2.Wfm.csv', delimiter=';', names=['near_end', 'far_end'])
ustrip_signal_3_3 = pd.read_csv('../data/ustrip2.Wfm.csv', delimiter=';', names=['near_end', 'far_end'])

# %%
################## 3.3V plots ##################

time_start = 32
window_length = 125000
time_delta = (0.000140214-0.000140014)*1e9

###### Microstrup/ustrip ######
ustrip_start_idx = int(time_start * 500000/200)
ustrip_end_idx = ustrip_start_idx + window_length
x_ustrip = np.linspace(0, time_delta * window_length/500000, window_length)

###### Stripline ######
strip_start_idx = int(time_start * 500000/200)
strip_end_idx = ustrip_start_idx + window_length
x_strip = np.linspace(0, time_delta * window_length/500000, window_length)

###### Broadside #####
broad_start_idx = int(time_start * 500000/200)
broad_end_idx = ustrip_start_idx + window_length
x_broad = np.linspace(0, time_delta * window_length/500000, window_length)

"""
broad_signal_3_3_start = 0
broad_signal_3_3_end = (0.000140214-0.000140014)*1e9
broad_signal_3_3_length = broad_signal_3_3.shape[0]

broad_signal_3_3_linspace = np.linspace(broad_signal_3_3_start, broad_signal_3_3_end,
                                        num=broad_signal_3_3_length)
"""

##### Plots #####
fig, ax = plt.subplots(2,3)
fig.set_figheight(7)
fig.set_figwidth(12)

##### Common stuff #####
ax[0,0].set_ylabel('Near End')
ax[1,0].set_ylabel('Far End')

###### Microstrup/ustrip ######
ax[0,0].plot(x_ustrip, ustrip_signal_3_3['near_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000, color='blue', linewidth=0.75)
ax[1,0].plot(x_ustrip, ustrip_signal_3_3['far_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000, color='orange', linewidth=0.75)

ax[0,0].grid()
ax[1,0].grid()
ax[0,0].set_title('Microstrip')
ax[0,0].set_ylim([-200, 235])
ax[1,0].set_ylim([-200, 235])

###### Microstrup/ustrip ######
ax[0,1].plot(x_strip, strip_signal_3_3['near_end'][strip_start_idx:strip_start_idx+window_length]*1000, color='blue', linewidth=0.75)
ax[1,1].plot(x_strip, strip_signal_3_3['far_end'][strip_start_idx:strip_start_idx+window_length]*1000, color='orange', linewidth=0.75)

ax[0,1].grid()
ax[1,1].grid()
ax[0,1].set_title('Stripline')
ax[0,1].set_ylim([-200, 235])
ax[1,1].set_ylim([-200, 235])

###### Broadside ######
ax[0,2].plot(x_broad, broad_signal_3_3['near_end'][broad_start_idx:broad_start_idx+window_length]*1000, color='blue', linewidth=0.75)
ax[1,2].plot(x_broad, broad_signal_3_3['far_end'][broad_start_idx:broad_start_idx+window_length]*1000, color='orange', linewidth=0.75)

ax[0,2].grid()
ax[1,2].grid()
ax[0,2].set_title('Broadside')
ax[0,2].set_ylim([-200, 235])
ax[1,2].set_ylim([-200, 235])


##### Common #####
fig.supylabel('Voltage [mV]')
fig.supxlabel('Time [ns]')
plt.show()

fig.savefig('../latex/imgs/measured_245v.pdf', bbox_inches='tight')

# %%
ustrip_max_next = (ustrip_signal_3_3['near_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).max
print(f'Microstrip NEXT: {ustrip_max_next()}')
ustrip_min_next = (ustrip_signal_3_3['near_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).min
print(f'Microstrip NEXT: {ustrip_min_next()}')
ustrip_max_fext = (ustrip_signal_3_3['far_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).max
print(f'Microstrip FEXT: {ustrip_max_fext()}')
ustrip_min_fext = (ustrip_signal_3_3['far_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).min
print(f'Microstrip FEXT: {ustrip_min_fext()}')

stripline_max_next = (strip_signal_3_3['near_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).max
print(f'Stripline NEXT: {stripline_max_next()}')
stripline_min_next = (strip_signal_3_3['near_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).min
print(f'Stripline NEXT: {stripline_min_next()}')
stripline_max_fext = (strip_signal_3_3['far_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).max
print(f'Stripline FEXT: {stripline_max_fext()}')
stripline_min_fext = (strip_signal_3_3['far_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).min
print(f'Stripline FEXT: {stripline_min_fext()}')

broadside_max_next = (broad_signal_3_3['near_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).max
print(f'Broadside NEXT: {broadside_max_next()}')
broadside_min_next = (broad_signal_3_3['near_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).min
print(f'Broadside NEXT: {broadside_min_next()}')
broadside_max_fext = (broad_signal_3_3['far_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).max
print(f'Broadside FEXT: {broadside_max_fext()}')
broadside_min_fext = (broad_signal_3_3['far_end'][ustrip_start_idx:ustrip_start_idx+window_length]*1000).min
print(f'Broadside FEXT: {broadside_min_fext()}')
# Out:
# Microstrip NEXT: 102.7668
# Microstrip NEXT: -69.169961
# Microstrip FEXT: 167.98419
# Microstrip FEXT: -100.79052
# Stripline NEXT: 96.83794499999999
# Stripline NEXT: -67.19368
# Stripline FEXT: 134.38736
# Stripline FEXT: -106.71937
# Broadside NEXT: 152.17391
# Broadside NEXT: -110.67193999999999
# Broadside FEXT: 225.29644
# Broadside FEXT: -181.81819

# %%
"""
We find the indexes for the times we want to average in the waveforms.
This is actually retarted but it should work???
"""

for i in range(len(x_ustrip)):
    if x_ustrip[i] >= 12:
        print(i)
        break
for i in range(len(x_ustrip)):
    if x_ustrip[i] >= 27:
        print(i)
        break
for i in range(len(x_ustrip)):
    if x_ustrip[i] >= 40:
        print(i)
        break
for i in range(len(x_ustrip)):
    if x_ustrip[i] >= 50:
        print(i)
        break
# Out:
# 30000
# 67500
# 100000
# 124999

# %%
ustrip_next_mean = np.mean(ustrip_signal_3_3['near_end'][ustrip_start_idx:ustrip_start_idx+window_length][30000:67500])*1000
ustrip_fext_mean = np.mean(ustrip_signal_3_3['far_end'][ustrip_start_idx:ustrip_start_idx+window_length][30000:67500])*1000
strip_next_mean = np.mean(strip_signal_3_3['near_end'][strip_start_idx:strip_start_idx+window_length][30000:67500])*1000
strip_fext_mean = np.mean(strip_signal_3_3['far_end'][strip_start_idx:strip_start_idx+window_length][30000:67500])*1000
broad_next_mean = np.mean(broad_signal_3_3['near_end'][broad_start_idx:broad_start_idx+window_length][30000:67500])*1000
broad_fext_mean = np.mean(broad_signal_3_3['far_end'][broad_start_idx:broad_start_idx+window_length][30000:67500])*1000

ustrip_next_mean_low = np.mean(ustrip_signal_3_3['near_end'][ustrip_start_idx:ustrip_start_idx+window_length][100000:124999])*1000
ustrip_fext_mean_low = np.mean(ustrip_signal_3_3['far_end'][ustrip_start_idx:ustrip_start_idx+window_length][100000:124999])*1000
strip_next_mean_low = np.mean(strip_signal_3_3['near_end'][strip_start_idx:strip_start_idx+window_length][100000:124999])*1000
strip_fext_mean_low = np.mean(strip_signal_3_3['far_end'][strip_start_idx:strip_start_idx+window_length][100000:124999])*1000
broad_next_mean_low = np.mean(broad_signal_3_3['near_end'][broad_start_idx:broad_start_idx+window_length][100000:124999])*1000
broad_fext_mean_low = np.mean(broad_signal_3_3['far_end'][broad_start_idx:broad_start_idx+window_length][100000:124999])*1000

print(f'Microstrip NEXT mean: {ustrip_next_mean}')
print(f'Microstrip FEXT mean: {ustrip_fext_mean}')
print(f'Stripline NEXT mean: {strip_next_mean}')
print(f'Stripline FEXT mean: {strip_fext_mean}')
print(f'Broadside NEXT mean: {broad_next_mean}')
print(f'Broadside FEXT mean: {broad_fext_mean}')

print(f'Microstrip NEXT mean: {ustrip_next_mean_low}')
print(f'Microstrip FEXT mean: {ustrip_fext_mean_low}')
print(f'Stripline NEXT mean: {strip_next_mean_low}')
print(f'Stripline FEXT mean: {strip_fext_mean_low}')
print(f'Broadside NEXT mean: {broad_next_mean_low}')
print(f'Broadside FEXT mean: {broad_fext_mean_low}')
# Out:
# Microstrip NEXT mean: 2.033675880413333
# Microstrip FEXT mean: 3.7503030456159996
# Stripline NEXT mean: 1.76706192948
# Stripline FEXT mean: 3.2767325217733325
# Broadside NEXT mean: 2.9044532450559997
# Broadside FEXT mean: 3.9881422848880006
# Microstrip NEXT mean: 0.7497533084923395
# Microstrip FEXT mean: 2.538915794719789
# Stripline NEXT mean: 2.1347099068602744
# Stripline FEXT mean: 2.810863402696107
# Broadside NEXT mean: 1.6166654809912393
# Broadside FEXT mean: 1.45737055025801
